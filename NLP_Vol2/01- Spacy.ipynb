# %% [markdown]
# # Installing the libraries
#
# - spaCy: https://spacy.io/

# %%
# %%capture
# !pip install spacy --upgrade

# %%
import numpy as np
import spacy

print(spacy.__version__)
# Out:
# 3.2.2

# %%
#!python -m spacy donwload pt_core_web_sm
#!python -m spacy donwload fr_core_web_sm
# %%capture
# !python -m spacy download en_core_web_sm

# %% [markdown]
# # POS (part-of-speech)
#
# - POS (part-of-speech): noun, adjective, verb
# - It is important to find named entities
# - Tags: https://ashutoshtripathi.com/2020/04/13/parts-of-speech-tagging-and-dependency-parsing-using-spacy-nlp/

# %%
nlp = spacy.load("en_core_web_sm")
nlp

# %%
doc = nlp("I am learning natural language processing. The course is in London")

# %% [markdown]
# ## Legend
#
# - lemma: "root" of the word
# - pos: part-of-speech
# - tag: morfological information (present, future, past)
# - dep: syntatic dependency
# - shape: lowercase, uppercasa
# - alpha: if it is alphanumeric
# - stop: if it is a stop word

# %%
for token in doc:
    print(token.text,token.pos_,token.lemma_,token.tag_,token.dep_,token.shape_,token.is_alpha,token.is_stop)
# Out:
# I PRON I PRP nsubj X True True
# am AUX be VBP aux xx True True
# learning VERB learn VBG ROOT xxxx True False
# natural ADJ natural JJ amod xxxx True False
# language NOUN language NN compound xxxx True False
# processing NOUN processing NN dobj xxxx True False
# . PUNCT . . punct . False False
# The DET the DT det Xxx True True
# course NOUN course NN nsubj xxxx True False
# is AUX be VBZ ROOT xx True True
# in ADP in IN prep xx True True
# London PROPN London NNP pobj Xxxxx True False

# %%
for token in doc:
    if token.pos_ == "PROPN":
        print(token.text)
# Out:
# London

# %%
for token in doc:
    if token.pos_ == "VERB":
        print(token.text)
# Out:
# learning

# %% [markdown]
# # Lemmatization and stemming
#
# - Lemmatization: meaning of the word based on the dictionary (morphological analysis) - extract the base word
# - Stemming: extract the root of the word

# %%
import nltk
stemmer = nltk.stem.PorterStemmer()

# %%
for token in doc:
    print(f"Original : {token.text:10}", f"Lemmatization : {token.lemma_:10}", f"Stemming : {stemmer.stem(token.text)}")
# Out:
# Original : I          Lemmatization : I          Stemming : I
# Original : am         Lemmatization : be         Stemming : am
# Original : learning   Lemmatization : learn      Stemming : learn
# Original : natural    Lemmatization : natural    Stemming : natur
# Original : language   Lemmatization : language   Stemming : languag
# Original : processing Lemmatization : processing Stemming : process
# Original : .          Lemmatization : .          Stemming : .
# Original : The        Lemmatization : the        Stemming : the
# Original : course     Lemmatization : course     Stemming : cours
# Original : is         Lemmatization : be         Stemming : is
# Original : in         Lemmatization : in         Stemming : in
# Original : London     Lemmatization : London     Stemming : london

# %%
doc1 = nlp("learn learning watch watching watched")
[token.lemma_ for token in doc1],[stemmer.stem(token.text) for token in doc1]
# Out:
# (['learn', 'learn', 'watch', 'watch', 'watch'],
#  ['learn', 'learn', 'watch', 'watch', 'watch'])

# %% [markdown]
# # Named-entity recognition (NER)
#
# - List of tags: https://towardsdatascience.com/named-entity-recognition-ner-using-spacy-nlp-part-4-28da2ece57c6

# %%
doc2 = nlp("IBM is a US company on information technology. Is is located in San Franscisco and revenue in 2018 was approximately 320 billion dolars")

# %%
for ent in doc2.ents:
    print(f"Original Entity: {ent.text:20}", f"Label : {ent.label_:10}")
# Out:
# Original Entity: IBM                  Label : ORG
# Original Entity: US                   Label : GPE
# Original Entity: San Franscisco       Label : GPE
# Original Entity: 2018                 Label : DATE
# Original Entity: approximately 320 billion Label : MONEY

# %%
from spacy import displacy
displacy.render(doc2,style = "ent",jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IBM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  company on information technology. Is is located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Franscisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and revenue in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     approximately 320 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  dolars</div></span>

# %%
doc3 = nlp("Bill Gates was born in Seattle on 1955-10-28 and is the founder of Microsoft")
displacy.render(doc3, style = "ent",jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Gates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seattle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1955-10-28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and is the founder of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %%
for ent in doc3.ents:
    print(f"Original Entity: {ent.text:20}", f"Label : {ent.label_:10}")
# Out:
# Original Entity: Bill Gates           Label : PERSON
# Original Entity: Seattle              Label : GPE
# Original Entity: 1955-10-28           Label : DATE
# Original Entity: Microsoft            Label : ORG

# %%
for ent in doc3.ents:
    if ent.label_ == "PERSON":
        print(f"Original Entity: {ent.text:20}", f"Label : {ent.label_:10}")
# Out:
# Original Entity: Bill Gates           Label : PERSON

# %% [markdown]
# # StopWords
#
# - Words that appear very often and don't help to understand the context of the document

# %%
from spacy.lang.en.stop_words import STOP_WORDS

print(STOP_WORDS)
# Out:
# {'yet', 'with', 'beforehand', 'one', 'everywhere', 'whence', 'call', 'will', 'during', 'namely', 'nine', 'n‘t', 'less', 'again', 'first', 'your', '‘d', 'noone', 'nowhere', 'had', 'below', "'ll", 'whatever', 'thereby', 'doing', 'itself', 'thus', "'re", 'really', '’ll', 'show', 'yourselves', 'also', 'ca', 'take', 'its', 'everything', 'anyhow', 'eleven', 're', 'over', 'since', 'been', 'before', 'even', 'on', 'therefore', 'made', 'being', 'a', 'he', 'within', '’m', 'never', '‘m', 'every', 'except', 'whoever', 'became', 'six', 'please', 'for', 'n’t', 'yours', 'onto', 'these', '‘ve', 'however', 'mine', 'many', 'though', 'others', 'part', 'whether', 'once', 'not', 'still', 'go', 'unless', 'through', 'otherwise', 'so', 'last', 'all', 'five', 'how', 'own', '’ve', 'after', 'sometime', 'should', 'more', 'something', 'such', 'former', 'be', 'here', 'various', 'wherein', 'thence', 'see', 'seems', 'seemed', 'anyone', 'themselves', 'each', 'this', 'whereafter', 'where', 'either', 'hereby', '‘s', 'nothing', 'are', 'done', 'then', 'but', 'nobody', 'none', '’s', 'who', 'whither', 'him', 'most', 'wherever', "'s", 'somewhere', 'against', 'i', 'which', 'until', 'twenty', 'or', 'she', '’re', 'upon', 'same', 'full', 'latterly', 'whereas', 'neither', 'together', 'back', 'have', 'say', '’d', 'we', 'no', 'into', 'much', 'seeming', 'to', 'perhaps', 'along', 'used', 'me', 'amongst', 'put', 'in', 'empty', 'of', 'someone', "'ve", 'two', 'becoming', 'although', 'becomes', 'do', 'serious', 'across', 'twelve', 'somehow', 'and', 'side', 'meanwhile', 'whereupon', 'behind', 'four', "'m", 'least', 'ours', 'another', 'any', 'beside', 'whom', 'moreover', 'give', 'anything', 'towards', 'there', 'as', 'around', 'next', 'seem', 'keep', 'therein', 'fifty', 'my', 'hereupon', 'bottom', 'third', 'always', 'beyond', 'anyway', 'must', 'nor', 'three', 'does', 'them', 'the', '‘ll', 'than', 'above', 'between', 'did', 'formerly', 'an', 'become', 'those', 'often', 'it', 'everyone', 'quite', 'regarding', 'from', 'at', 'what', 'am', 'while', 'whereby', 'their', 'may', 'afterwards', 'because', 'almost', 'else', 'our', 'us', 'get', 'ever', 'top', 'without', 'fifteen', 'is', 'hereafter', 'can', 'hundred', 'you', 'thru', 'whole', 'enough', 'when', 'off', 'few', 'very', 'about', 'has', 'sixty', 'they', 'make', 'forty', 'up', "'d", 'mostly', '‘re', 'both', 'nevertheless', 'rather', 'amount', 'herein', 'front', 'besides', 'per', 'under', 'himself', 'could', 'cannot', 'too', 'herself', 'well', 'using', 'elsewhere', 'only', 'thereafter', 'myself', 'by', 'out', 'thereupon', 'due', 'indeed', 'toward', 'hence', 'among', 'that', 'was', 'name', 'further', 'his', 'if', 'whose', 'alone', 'were', 'now', 'might', 'would', 'whenever', 'other', 'down', 'anywhere', 'move', 'why', 'ten', 'ourselves', 'already', 'yourself', 'just', 'sometimes', 'her', 'hers', "n't", 'via', 'some', 'several', 'eight', 'throughout', 'latter'}

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
"it" in STOP_WORDS
# Out:
# True

# %%
nlp.vocab["it"].is_stop,nlp.vocab["walk"].is_stop
# Out:
# (True, False)

# %%
doc4 = nlp("I am learning natural language processing. The course is in London")
for token in doc:
    if nlp.vocab[token.text].is_stop:
        print(token.text)
# Out:
# I
# am
# The
# is
# in

# %%
doc4 = nlp("I am learning natural language processing. The course is in London")
for token in doc:
    if not nlp.vocab[token.text].is_stop:
        print(token.text)
# Out:
# learning
# natural
# language
# processing
# .
# course
# London

# %% [markdown]
# # Dependency parsing
#
# - Parent-child relation

# %%
doc5 = nlp("book a ticket from London to Paris")
for token in doc5:
        print(f"Original Entity: {token.text:20}", f"Dep : {token.dep_:10}")
# Out:
# Original Entity: book                 Dep : ROOT
# Original Entity: a                    Dep : det
# Original Entity: ticket               Dep : dobj
# Original Entity: from                 Dep : prep
# Original Entity: London               Dep : pobj
# Original Entity: to                   Dep : prep
# Original Entity: Paris                Dep : pobj

# %%
origin = doc5[4]
destiny = doc5[6]
print(origin,destiny)
# Out:
# London Paris

# %%
# ancestors -- > Atalar
list(origin.ancestors),list(destiny.ancestors)
# Out:
# ([from, ticket, book], [to, book])

# %% [markdown]
# ---

# %%
doc5[0],doc5[2],doc5[0].is_ancestor(doc5[2])
# Out:
# (book, ticket, True)

# %%
doc6 = nlp("book a table for the restaurant and a taxi to the hotel")

tasks = doc6[2],doc6[8]
locations = doc6[5],doc6[11]

print(tasks,locations)
# Out:
# (table, taxi) (restaurant, hotel)

# %%
for local in locations:
    print("-----",local,"-----")
    for obj in local.ancestors:
        print(obj)
# Out:
# ----- restaurant -----
# for
# table
# book
# ----- hotel -----
# to
# taxi
# restaurant
# for
# table
# book

# %%
for local in locations:
    for obj in local.ancestors:
        if obj in tasks:
            print("Reservation of a {} to the {}".format(obj,local))
            break
# Out:
# Reservation of a table to the restaurant
# Reservation of a taxi to the hotel

# %%
doc6[5],list(doc6[5].children)
# Out:
# (restaurant, [the, and, taxi])

# %% [markdown]
# ---

# %%
from spacy import displacy

# %%
doc6
# Out:
# book a table for the restaurant and a taxi to the hotel

# %%
# !!!
doc6[5],list(doc6[5].children)
# Out:
# (restaurant, [the, and, taxi])

# %%
displacy.render(doc6, style = "dep",jupyter = True,options = {"distance":90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9bbd81065c734c98bb3e237bb052abe1-0" class="displacy" width="1130" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">book</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">table</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">restaurant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">taxi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">hotel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-0" stroke-width="2px" d="M160,137.0 C160,92.0 220.0,92.0 220.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,139.0 L152,127.0 168,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-1" stroke-width="2px" d="M70,137.0 C70,47.0 225.0,47.0 225.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,139.0 L233.0,127.0 217.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-2" stroke-width="2px" d="M250,137.0 C250,92.0 310.0,92.0 310.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310.0,139.0 L318.0,127.0 302.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-3" stroke-width="2px" d="M430,137.0 C430,92.0 490.0,92.0 490.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,139.0 L422,127.0 438,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-4" stroke-width="2px" d="M340,137.0 C340,47.0 495.0,47.0 495.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M495.0,139.0 L503.0,127.0 487.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-5" stroke-width="2px" d="M520,137.0 C520,92.0 580.0,92.0 580.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M580.0,139.0 L588.0,127.0 572.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-6" stroke-width="2px" d="M700,137.0 C700,92.0 760.0,92.0 760.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M700,139.0 L692,127.0 708,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb3e237bb052abe1-0-7" stroke-width="2px" d="M520,137.0 C520,2.0 770.0,2.0 770.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-9bbd81065c734c98bb3e237bb052abe1-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,139.0 L778.0,127.0 762.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-9bbd81065c734c98bb

# %%
doc6[2],list(doc6[2].ancestors)
# Out:
# (table, [book])

# %%
doc6[2],list(doc6[2].children)
# Out:
# (table, [a, for])

# %% [markdown]
# ---

# %%
doc = nlp("What places can we visit in London and stay in Paris?")
locations = doc[6],doc[10]
actions = doc[4],doc[8]
print(locations,actions)
# Out:
# (London, Paris) (visit, stay)

# %%
[i for i in local.ancestors for local in locations],[i for i in local.ancestors for local in actions]
# Out:
# ([in, in, stay, stay, visit, visit], [in, in, stay, stay, visit, visit])

# %%
for local in locations:
    #print(local)
    for action in local.ancestors:
        if action in actions:
            print("{} to {}".format(local,action))
            break
# Out:
# London to visit
# Paris to stay

# %%
displacy.render(doc, style = "dep",jupyter = True,options = {"distance":90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cfa10d4b95a142d49fc97f2c891d9537-0" class="displacy" width="1040" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">places</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">visit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">London</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">stay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Paris?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-0" stroke-width="2px" d="M70,182.0 C70,137.0 125.0,137.0 125.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-1" stroke-width="2px" d="M160,182.0 C160,47.0 405.0,47.0 405.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,184.0 L152,172.0 168,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-2" stroke-width="2px" d="M250,182.0 C250,92.0 400.0,92.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,184.0 L242,172.0 258,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-3" stroke-width="2px" d="M340,182.0 C340,137.0 395.0,137.0 395.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340,184.0 L332,172.0 348,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-4" stroke-width="2px" d="M430,182.0 C430,137.0 485.0,137.0 485.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M485.0,184.0 L493.0,172.0 477.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-5" stroke-width="2px" d="M520,182.0 C520,137.0 575.0,137.0 575.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,184.0 L583.0,172.0 567.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-6" stroke-width="2px" d="M430,182.0 C430,47.0 675.0,47.0 675.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M675.0,184.0 L683.0,172.0 667.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-7" stroke-width="2px" d="M430,182.0 C430,2.0 770.0,2.0 770.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b95a142d49fc97f2c891d9537-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,184.0 L778.0,172.0 762.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cfa10d4b95a142d49fc97f2c891d9537-0-8" stroke-width="2px" d="M790,182.0 C790,137.0 845.0,137.0 845.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cfa10d4b9

# %%
# doc[4] --> visit
# doc[-4] --> stay

[i for i in doc[4].ancestors],[i for i in doc[-4].ancestors],list(doc[-4].children)
# Out:
# ([], [visit], [in])

# %% [markdown]
# # Similarity between words and sentences
#
# - spaCy uses the GloVe algorithm (Global Vectors for Word Representation)
# - Original paper: https://nlp.stanford.edu/pubs/glove.pdf

# %%
from warnings import filterwarnings
filterwarnings("ignore")

w1 = nlp("hello")
w2 = nlp("hi")
w3 = nlp("or")

# %%
w1.similarity(w2),w2.similarity(w1)
# Out:
# (0.6864077474207763, 0.6864077474207763)

# %%
w1.similarity(w3)
# Out:
# -0.030911659914285024

# %%
text1 = nlp('When will the new movie be released?')
text2 = nlp('The new movie will be released next month')
text3 = nlp('What color is the car?')

# %%
text1.similarity(text2),text1.similarity(text3)
# Out:
# (0.7480209003398514, 0.34528153350463103)

# %%
nlp("New York").similarity(nlp("Nw Yok"))
# Out:
# 0.6932173297338927

# %% [markdown]
# ---

# %%
text = nlp("cat dog horse person")

# %%
for token1 in text:
    print("----",token1,"----")
    for token2 in text:
        similarity = np.round(token1.similarity(token2) * 100,4)
        print("{} is {}% similar to {}".format(token1,similarity,token2))
    print()
# Out:
# ---- cat ----
# cat is 100.0% similar to cat
# cat is 51.4044% similar to dog
# cat is 62.119% similar to horse
# cat is 35.2274% similar to person
#
# ---- dog ----
# dog is 51.4044% similar to cat
# dog is 100.0% similar to dog
# dog is 57.2139% similar to horse
# dog is 37.0158% similar to person
#
# ---- horse ----
# horse is 62.119% similar to cat
# horse is 57.2139% similar to dog
# horse is 100.0% similar to horse
# horse is 40.7988% similar to person
#
# ---- person ----
# person is 35.2274% similar to cat
# person is 37.0158% similar to dog
# person is 40.7988% similar to horse
# person is 100.0% similar to person

# %% [markdown]
# # Tokenization

# %%
document1 = nlp('I am learning natural language processing. The course is in London. Ph.d John is coming')
for token in document1:
    print(token)
# Out:
# I
# am
# learning
# natural
# language
# processing
# .
# The
# course
# is
# in
# London
# .
# Ph.d
# John
# is
# coming

# %%
# Ph.d !!!
document2 = 'I am learning natural language processing. The course is in London. Ph.d John is coming'
document2.split('.')
# Out:
# ['I am learning natural language processing',
#  ' The course is in London',
#  ' Ph',
#  'd John is coming']
